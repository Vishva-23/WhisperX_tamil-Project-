# %% [markdown]
# <a href="https://colab.research.google.com/github/Vishva-23/WhisperX_tamil-Project-/blob/main/WhisperX_tamil.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --q git+https://github.com/m-bain/whisperx.git
# Out:
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 7.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 208.7/208.7 kB 8.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.9/32.9 MB 29.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.9/35.9 MB 14.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 89.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 5.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 81.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 10.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.5/58.5 kB 6.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.1/48.1 kB 5.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.4/51.4 kB 6.5 MB/s eta 0:00:00
# ...

# %%
import site
print(site.getsitepackages())
# Out:
# ['/usr/local/lib/python3.10/dist-packages', '/usr/lib/python3/dist-packages', '/usr/lib/python3.10/dist-packages']

# %%
import whisperx

# %%
# Out:
# No language specified, language will be first be detected for each audio file (increases inference time).
# INFO:pytorch_lightning.utilities.migration.utils:Lightning automatically upgraded your loaded checkpoint from v1.5.4 to v2.2.0.post0. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint ../root/.cache/torch/whisperx-vad-segmentation.bin`
# Model was trained with pyannote.audio 0.0.1, yours is 3.1.1. Bad things might happen unless you revert pyannote.audio to 0.x.
# Model was trained with torch 1.10.0+cu102, yours is 2.1.0+cu121. Bad things might happen unless you revert torch to 1.x.
# Detected language: ta (0.99) in first 30s of audio...
# ...

# %%
# Out:
# SPEAKER_01: உனக்குப் பிடித்ததைச் செய்துகொள். ஆனால் ஒரு கண்டிஷன். உனக்கு ஒரு வருடம்தான் நேரம். நீ யார் என்பதை அப்பாவிற்குத் தொடர்புகொள்வதுபோல் ஏதாவது செய்துகொள். உனக்கு இப்போது புரியாது ஐயா. ஓரும் தாய் இல்லாப்பிள்ளையை இப்படித் தரதலையாக வளர்த்தான் என்று என்ன தாயாகச் சொல்வார
# SPEAKER_02: நன்றி அப்பா. நன்றி அப்பா. செரி அப்பா. நீ செய்யச் சொல் அம்மா.
# 'SPEAKER_01: உனக்குப் பிடித்ததைச் செய்துகொள். ஆனால் ஒரு கண்டிஷன். உனக்கு ஒரு வருடம்தான் நேரம். நீ யார் என்பதை அப்பாவிற்குத் தொடர்புகொள்வதுபோல் ஏதாவது செய்துகொள். உனக்கு இப்போது புரியாது ஐயா. ஓரும் தாய் இல்லாப்பிள்ளையை இப்படித் தரதலையாக வளர்த்தான் என்று என்ன தாயாகச் சொல்வார\nSPEAKER_02: நன்றி அப்பா. நன்றி அப்பா. செரி அப்பா. நீ செய்யச் சொல் அம்மா.'

# %%
device = "cpu"
batch_size = 2 # reduce if low on GPU mem
compute_type = "int8" # change to "int8" if low on GPU mem (may reduce accuracy)

# %%
audio_file = r"/content/audio.wav"

# %%
audio = whisperx.load_audio(audio_file)

# %%
model = whisperx.load_model("large-v2", device, compute_type=compute_type)
# Out:
# tokenizer.json:   0%|          | 0.00/2.20M [00:01<?, ?B/s]
# vocabulary.txt:   0%|          | 0.00/460k [00:01<?, ?B/s]
# config.json:   0%|          | 0.00/2.80k [00:01<?, ?B/s]
# model.bin:   0%|          | 0.00/3.09G [00:00<?, ?B/s]
# No language specified, language will be first be detected for each audio file (increases inference time).
# 100%|█████████████████████████████████████| 16.9M/16.9M [00:02<00:00, 6.45MiB/s]
# INFO:pytorch_lightning.utilities.migration.utils:Lightning automatically upgraded your loaded checkpoint from v1.5.4 to v2.2.0.post0. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint ../root/.cache/torch/whisperx-vad-segmentation.bin`
# Model was trained with pyannote.audio 0.0.1, yours is 3.1.1. Bad things might happen unless you revert pyannote.audio to 0.x.
# Model was trained with torch 1.10.0+cu102, yours is 2.1.0+cu121. Bad things might happen unless you revert torch to 1.x.

# %%
import torch

# %%
#Load audio and transcribe
result = model.transcribe(audio, batch_size=batch_size)
print(result["segments"]) #before alignment
# Out:
# Detected language: en (0.94) in first 30s of audio...
# [{'text': " when you're sleeping. And what it's done is it has connected us completely to the world. And because of the phone, and then you build everything around it. Once you start getting used to global content and global comparisons, then you know, what you eat, what you read, what you think, everything becomes global. We are, I mean, that's why they call it globalization. Okay.", 'start': 0.009, 'end': 29.224}, {'text': " Simple question for you. Who is Dr. S.J. Shankar the man that people don't know? I'll tell you why. Right now, you're very popular on Shorts and Reels for your very aggressive comebacks. And your very aggressive responses. And in many ways, I feel like... There's a slight age difference between us. No, but you're still the guy young India is cheering for. When we see you up there talking to all these people from other countries...", 'start': 29.667, 'end': 54.684}]

# %%
# 2. Align whisper output
model_a, metadata = whisperx.load_align_model(language_code=result["language"], device=device)
result = whisperx.align(result["segments"], model_a, metadata, audio, device, return_char_alignments=False)
# Out:
# Downloading: "https://download.pytorch.org/torchaudio/models/wav2vec2_fairseq_base_ls960_asr_ls960.pth" to /root/.cache/torch/hub/checkpoints/wav2vec2_fairseq_base_ls960_asr_ls960.pth
# 100%|██████████| 360M/360M [00:08<00:00, 44.0MB/s]

# %%
result
# Out:
# {'segments': [{'start': 0.189,
#    'end': 0.869,
#    'text': " when you're sleeping.",
#    'words': [{'word': 'when', 'start': 0.189, 'end': 0.309, 'score': 0.526},
#     {'word': "you're", 'start': 0.329, 'end': 0.469, 'score': 0.646},
#     {'word': 'sleeping.', 'start': 0.489, 'end': 0.869, 'score': 0.766}]},
#   {'start': 1.65,
#    'end': 5.132,
#    'text': "And what it's done is it has connected us completely to the world.",
#    'words': [{'word': 'And', 'start': 1.65, 'end': 1.73, 'score': 0.239},
#     {'word': 'what', 'start': 1.75, 'end': 1.89, 'score': 0.896},
#     {'word': "it's", 'start': 1.95, 'end': 2.09, 'score': 0.768},
#     {'word': 'done', 'start': 2.13, 'end': 2.33, 'score': 0.966},
#     {'word': 'is', 'start': 2.41, 'end': 2.49, 'score': 0.944},
#     {'word': 'it', 'start': 2.55, 'end': 2.63, 'score': 0.848},
#     {'word': 'has', 'start': 2.951, 'end': 3.071, 'score': 0.556},
#     {'word': 'connected', 'start': 3.151, 'end': 3.571, 'score': 0.949},
# ...

# %%
diarize_model = whisperx.DiarizationPipeline(use_auth_token="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",
                                             device=device)

# %%
diarize_segments = diarize_model(audio, min_speakers=2, max_speakers=2)

# %%
diarize_segments
# Out:
#                               segment label     speaker      start        end
# 0   [ 00:00:00.008 -->  00:00:01.010]     A  SPEAKER_00   0.008489   1.010187
# 1   [ 00:00:01.010 -->  00:00:01.502]     B  SPEAKER_01   1.010187   1.502547
# 2   [ 00:00:01.502 -->  00:00:05.254]     C  SPEAKER_00   1.502547   5.254669
# 3   [ 00:00:05.390 -->  00:00:05.814]     D  SPEAKER_01   5.390492   5.814941
# 4   [ 00:00:05.814 -->  00:00:05.865]     E  SPEAKER_00   5.814941   5.865874
# 5   [ 00:00:06.528 -->  00:00:11.061]     F  SPEAKER_00   6.528014  11.061121
# 6   [ 00:00:11.587 -->  00:00:11.910]     G  SPEAKER_00  11.587436  11.910017
# 7   [ 00:00:12.453 -->  00:00:16.833]     H  SPEAKER_00  12.453311  16.833616
# 8   [ 00:00:17.359 -->  00:00:17.733]     I  SPEAKER_00  17.359932  17.733447
# 9   [ 00:00:18.242 -->  00:00:21.655]     J  SPEAKER_00  18.242784  21.655348
# 10  [ 00:00:21.926 -->  00:00:22.911]     K  SPEAKER_00  21.926995  22.911715
# ...

# %%
result = whisperx.assign_word_speakers(diarize_segments, result)
print(diarize_segments)
print(result["segments"]) # segments are now assigned speaker IDs
# Out:
#                               segment label     speaker      start        end  \
# 0   [ 00:00:00.008 -->  00:00:01.010]     A  SPEAKER_00   0.008489   1.010187
# 1   [ 00:00:01.010 -->  00:00:01.502]     B  SPEAKER_02   1.010187   1.502547
# 2   [ 00:00:01.502 -->  00:00:05.254]     C  SPEAKER_00   1.502547   5.254669
# 3   [ 00:00:05.390 -->  00:00:05.814]     D  SPEAKER_02   5.390492   5.814941
# 4   [ 00:00:05.814 -->  00:00:05.865]     E  SPEAKER_00   5.814941   5.865874
# 5   [ 00:00:06.528 -->  00:00:11.061]     F  SPEAKER_00   6.528014  11.061121
# 6   [ 00:00:11.587 -->  00:00:11.910]     G  SPEAKER_00  11.587436  11.910017
# 7   [ 00:00:12.453 -->  00:00:16.833]     H  SPEAKER_00  12.453311  16.833616
# 8   [ 00:00:17.359 -->  00:00:17.733]     I  SPEAKER_00  17.359932  17.733447
# 9   [ 00:00:18.242 -->  00:00:21.655]     J  SPEAKER_00  18.242784  21.655348
# 10  [ 00:00:21.926 -->  00:00:22.911]     K  SPEAKER_00  21.926995  22.911715
# ...

# %%
result
# Out:
# {'segments': [{'start': 0.189,
#    'end': 0.869,
#    'text': " when you're sleeping.",
#    'words': [{'word': 'when',
#      'start': 0.189,
#      'end': 0.309,
#      'score': 0.526,
#      'speaker': 'SPEAKER_00'},
#     {'word': "you're",
#      'start': 0.329,
#      'end': 0.469,
#      'score': 0.646,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'sleeping.',
#      'start': 0.489,
#      'end': 0.869,
#      'score': 0.766,
#      'speaker': 'SPEAKER_00'}],
#    'speaker': 'SPEAKER_00'},
#   {'start': 1.65,
#    'end': 5.132,
#    'text': "And what it's done is it has connected us completely to the world.",
#    'words': [{'word': 'And',
#      'start': 1.65,
#      'end': 1.73,
#      'score': 0.239,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'what',
#      'start': 1.75,
#      'end': 1.89,
#      'score': 0.896,
#      'speaker': 'SPEAKER_00'},
#     {'word': "it's",
#      'start': 1.95,
#      'end': 2.09,
#      'score': 0.768,
# ...

# %%
# Assuming result is the dictionary containing segments as described in your code

current_speaker = None
current_dialogue = ''

for segment in result['segments']:
    speaker = segment['speaker']
    text = segment['text']
    words = segment['words']
    dialogue = ' '.join([word['word'] for word in words])

    if current_speaker == speaker:
        current_dialogue += ' ' + dialogue
    else:
        if current_speaker is not None:
            print(f"{current_speaker}: {current_dialogue}")
        current_speaker = speaker
        current_dialogue = dialogue

# Print the last dialogue
if current_speaker is not None:
    print(f"{current_speaker}: {current_dialogue}")
# Out:
# SPEAKER_00: when you're sleeping. And what it's done is it has connected us completely to the world. And because of the phone, and then you build everything around it. Once you start getting used to global content and global comparisons, then you know, what you eat, what you read, what you think, everything becomes global. We are, I mean, that's why they call it globalization.
# SPEAKER_02: Okay. Simple question for you. Who is Dr. S.J. Shankar the man that people don't know? I'll tell you why. Right now, you're very popular on Shorts and Reels for your very aggressive comebacks. And your very aggressive responses. And in many ways, I feel like... There's a slight age difference between us. No, but you're still the guy young India is cheering for. When we see you up there talking to all these people from other countries...

# %%
from transformers import MBartForConditionalGeneration, MBart50TokenizerFast

def translate_text(text, source_lang="ta_IN", target_lang="en_XX"):
    # Load pretrained mBART model and tokenizer
    model_name = "facebook/mbart-large-50-many-to-one-mmt"
    model = MBartForConditionalGeneration.from_pretrained(model_name)
    tokenizer = MBart50TokenizerFast.from_pretrained(model_name)

    # Tokenize input text
    inputs = tokenizer(text, return_tensors="pt", max_length=1024, truncation=True)

    # Perform translation
    outputs = model.generate(**inputs, forced_bos_token_id=tokenizer.lang_code_to_id[source_lang], forced_eos_token_id=tokenizer.lang_code_to_id[target_lang])

    # Decode translated text
    translated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return translated_text

translate_text(current_dialogue)

# %%
# Out:
# Translated speaker: SPEAKER_01
